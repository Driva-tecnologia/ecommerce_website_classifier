# %%
import pandas as pd
from tqdm import tqdm
from bs4 import BeautifulSoup
import re
import os
import unicodedata
import pickle
from pprint import pprint

import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report, make_scorer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import roc_curve, RocCurveDisplay
from sklearn.model_selection import train_test_split

# %%
df_validated = pd.read_csv('../data/countries_predictions_sample_simple_validated.csv')
df = pd.read_csv('../data/countries_predictions_sample_2.csv')

# %%
df_validated = df_validated[['domain','true_prediction','notes']]

# %%
df = df.merge(df_validated, on=['domain'])

# %%
len(df)
# Out:
# 96

# %%
df.head()
# Out:
#    Unnamed: 0                     domain  \
# 0           0       corpoeenergia.com.br
# 1           1          donnalimao.com.br
# 2           2       insumosdailha.com.br
# 3           3           primelive.com.br
# 4           4  santodesejosexshop.com.br
#
#                                                 html  \
# 0  <!DOCTYPE html>\n<!--[if lt IE 7]>      <html ...
# 1  <!doctype html>\n<html lang="pt-br" data-tray-...
# 2  <!DOCTYPE html><html lang="pt-BR" xmlns:og="ht...
# 3  <!doctype html>\n<html lang="pt-br" class="pag...
# 4  <!doctype html>\n<html lang="pt-BR">\n<head>\n...
#
#                                               tokens     processed_cnpjs  \
# 0  ['java', 'script', 'parecer', 'desabilitar', '...  ['17155356000105']
# 1  ['menu', 'vendido', 'lancamentos', 'conjunto',...                  []
# 2  ['fretar', 'gratis', 'brindar', 'exclusivo', '...  ['47542679000104']
# 3  ['primar', 'live', 'ajudar', 'suportar', 'cont...  ['03897520000137']
# 4  ['home', 'contar', 'carro', 'politicar', 'troc...                  []
#
#    has_cnpj  count_prices  has_prices  pred_0_prob  pred_1_prob  prediction  \
# 0      True            49        True     0.000170     0.999830           1
# 1     False            51        True     0.001667     0.998333           1
# 2      True            31        True     0.000566     0.999434           1
# 3      True            49        True     0.000266     0.999734           1
# 4     False            27        True     0.003864     0.996136           1
#
#   true_prediction notes
# 0            True   NaN
# 1            True   NaN
# 2            True   NaN
# 3            True   NaN
# 4             NaN   NaN

# %%
df = df.dropna(axis=0, subset='true_prediction')

# %%
df_wrong = df.loc[df['prediction'] != df['true_prediction']]
df_wrong
# Out:
#     Unnamed: 0                       domain  \
# 4            4    santodesejosexshop.com.br
# 12          12        santapaciencia.com.br
# 16          16      programapecamais.com.br
# 25          25            ladyfetish.com.br
# 34          34           postoeuropa.com.br
# 40          40      santaclaramoveis.com.br
# 42          42   adecomdistribuidora.com.br
# 48          48     cafeparacriativos.com.br
# 54          54   metropoleimoveisata.com.br
# 58          58             acrerifas.com.br
# 65          65                renato.tec.br
# 76          76  cascatadastresquedas.com.br
# 80          80      robinhocelulares.com.br
#
#                                                  html  \
# 4   <!doctype html>\n<html lang="pt-BR">\n<head>\n...
# 12  <!-- This page is cached by the Hummingbird Pe...
# 16  \r\n\r\n<!doctype html>\n<html lang="pt-BR" cl...
# 25  <!DOCTYPE html>\n<html lang="pt">\n<head>\n  \...
# 34  <!doctype html >\n<html lang="en" id="estilo_p...
# 40  <!DOCTYPE html>\r\n<html class="no-touch" lang...
# 42  <!DOCTYPE html>\n<!--[if IE 9 ]>   <html class...
# 48  <!DOCTYPE html>\n<html lang="pt-BR" class="no-...
# 54  <!DOCTYPE html>\r\n<html lang="pt-br">\r\n<hea...
# 58  <!DOCTYPE html><html lang="pt-BR"><head><scrip...
# 65  <!doctype html><html lang="en"><head><meta cha...
# 76  <!DOCTYPE html><html lang="en-US" itemscope it...
# 80  <!DOCTYPE html>\n<html class="no-js" lang="pt-...
#
#                                                tokens     processed_cnpjs  \
# 4   ['home', 'contar', 'carro', 'politicar', 'troc...                  []
# 12  ['skip', 'content', 'facebook', 'instagram', '...  ['31381211000145']
# 16  ['paginar', 'inicial', 'catalogar', 'produto',...                  []
# 25  ['top', 'page', 'iniciar', 'loja', 'contato', ...                  []
# 34  ['please', 'enable', 'java', 'script', 'contin...                  []
# 40  ['produto', 'armarios', 'bercos', 'cadeira', '...                  []
# 42  ['adecom', 'ruir', 'anne', 'frank', 'hauer', '...                  []
# 48  ['iniciar', 'sobrar', 'produto', 'loja', 'blog...                  []
# 54  ['barao', 'triunfar', 'aracatuba', 'contato', ...                  []
# 58  ['acrerifas', 'oficial', 'acre', 'premiacoes',...                  []
# 65  ['need', 'enable', 'java', 'script', 'run', 'a...                  []
# 76  ['search', 'site', 'skip', 'main', 'content', ...                  []
# 80  ['skip', 'content', 'robinho', 'celular', 'ass...                  []
#
#     has_cnpj  count_prices  has_prices  pred_0_prob  pred_1_prob  prediction  \
# 4      False            27        True     0.003864     0.996136           1
# 12      True            14        True     0.002818     0.997182           1
# 16     False             0       False     0.285620     0.714380           1
# 25     False            38        True     0.007775     0.992225           1
# 34     False             0       False     0.458468     0.541532           1
# 40     False             0       False     0.479948     0.520052           1
# 42     False             0       False     0.404961     0.595039           1
# 48     False             0       False     0.891333     0.108667           0
# 54     False            23        True     0.114849     0.885151           1
# 58     False             1       False     0.789300     0.210700           0
# 65     False             0       False     0.447231     0.552769           1
# 76     False             0       False     0.880950     0.119050           0
# 80     False             0       False     0.876017     0.123983           0
#
#    true_prediction                                              notes
# 4              NaN                                                NaN
# 12             NaN                                                NaN
# 16           False                                         Login page
# 25             NaN                                                NaN
# 34           False                                         Login page
# 40           False  Não é ecomm, mas tem produtos, permite carrinh...
# 42           False  Não é ecomm, mas tem produtos, permite carrinh...
# 48            True                                                NaN
# 54           False                                                NaN
# 58             NaN                                                NaN
# 65           False                                                NaN
# 76             NaN                                                NaN
# 80             NaN                                                NaN

# %%
import html
import re

def clean_html_string(html_str):
    # Primeiro, decodifique os caracteres de escape HTML
    decoded_str = html.unescape(html_str)
    
    # Em seguida, substitua \r, \n e \t por espaços em branco
    clean_str = re.sub(r'[\r\n\t]', ' ', decoded_str)
    
    # Opcionalmente, você pode remover múltiplos espaços consecutivos
    clean_str = re.sub(r'\s+', ' ', clean_str).strip()
    
    return clean_str

# clean_html_string(df.loc[df['domain'] == 'programapecamais.com.br']['html'].values[0])
clean_html_string(df.loc[df['domain'] == 'postoeuropa.com.br']['html'].values[0])

# %% [markdown]
# # Build model features on wrongly predicted data to assert reasoning

# %%
# Pre processamento
STOP_WORDS = (set(stopwords.words('portuguese'))).union(set(stopwords.words('english')))
lemmatizer = WordNetLemmatizer()

nltk.download("stopwords")
nltk.download("punkt")
nltk.download("wordnet")

def custom_tokenizer(html_text):
    try:
        # pegar somente o body do HTML
        soup = BeautifulSoup(html_text, "html.parser")
        text = soup.body.get_text() if soup.body else ""

        # pre processamento do texto
        # normalizar
        preprocessed_text = unicodedata.normalize("NFKD", text).encode("ASCII", "ignore").decode("utf-8")

        # lowercase
        preprocessed_text = preprocessed_text.lower()

        # substitui tudo que não é letra ou espaço por um espaço
        preprocessed_text = re.sub(r"[^a-zA-Z\s]", " ", preprocessed_text)

        # remover possives espaços repetidos
        preprocessed_text = re.sub(r"\s+", " ", preprocessed_text).strip()
  
        # tokenizar
        tokens = nltk.word_tokenize(preprocessed_text)

        # remover stopwords
        tokens = [
            token for token in tokens if token not in STOP_WORDS and len(token) > 2
        ]
        
        # Aplicar lemmatizer
        tokens = [lemmatizer.lemmatize(token) for token in tokens]

        return tokens

    except Exception as e:
        print(e)
        print("Failed on custom_tokenizer, passing...")
        return []

# %%
# Open picked model
serialized_model = open('../models/BEST_MODEL_ecomm_tfidf_vectorizer_ecomm_logistic_regression_lbfgs_lemmatizer_3_True_42_1000_ecomm_spiderwebv4_dataset_html.pkl', "rb")
model = pickle.load(serialized_model)
serialized_model.close()
# Open picked vectorizer
serialized_vectorizer = open('../models/BEST_VECTORIZER_ecomm_tfidf_vectorizer_ecomm_logistic_regression_lbfgs_lemmatizer_3_True_42_1000_ecomm_spiderwebv4_dataset_html.pkl', "rb")
vectorizer = pickle.load(serialized_vectorizer)
serialized_vectorizer.close()

# %%
vectorized_html = vectorizer.transform(df_wrong['html'])

# %%
len(df_wrong)
# Out:
# 13

# %%
vectorized_html.shape[0]

# %%
df_wrong['html_tokens'] = df_wrong['html'].apply(custom_tokenizer)

# %%
idf_values = vectorizer.idf_
feature_names = vectorizer.get_feature_names_out()
vectors = []
for row_idx, row in enumerate(vectorized_html.toarray()):
    vector_dict = {}
    for col_idx, tfidf_value in enumerate(row):
        if tfidf_value != 0.0:
            feature_name = feature_names[col_idx]
            idf_value = idf_values[col_idx]
            vector_dict[feature_name] = {'tfidf': tfidf_value, 'idf': idf_value}
    
    sorted_vector_dict = {k: v for k, v in sorted(vector_dict.items(), key=lambda item: item[1]['tfidf'], reverse=True)}
    vectors.append(sorted_vector_dict)

# Adicionar os vetores ao dataframe original
df_wrong['vectors'] = vectors

# %%
df_wrong

# %%
domains = df_wrong['domain'].tolist()
selected_domain = domains[2]
print(selected_domain)
pprint(df_wrong.loc[df['domain'] == selected_domain]['html_tokens'].tolist())
(df_wrong.loc[df['domain'] == selected_domain]['vectors'].values)[0]
# Out:
# programapecamais.com.br
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/git/accounting_website_classifier/venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'html_tokens'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 4
#       2 selected_domain = domains[2]
#       3 print(selected_domain)
# ----> 4 pprint(df_wrong.loc[df['domain'] == selected_domain]['html_tokens'].tolist())
#       5 (df_wrong.loc[df['domain'] == selected_domain]['vectors'].values)[0]
#
# File ~/git/accounting_website_classifier/venv/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/git/accounting_website_classifier/venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'html_tokens'

# %%
df
# Out:
#     Unnamed: 0                          domain  \
# 0            0            corpoeenergia.com.br
# 1            1               donnalimao.com.br
# 2            2            insumosdailha.com.br
# 3            3                primelive.com.br
# 4            4       santodesejosexshop.com.br
# ..         ...                             ...
# 91          91               roccianera.com.br
# 92          92                    eblog.com.br
# 93          93  blogtherainbow.blogspot.com.br
# 94          94   netfilmesmega.blogspot.com.br
# 95          95    diamanteshop.blogspot.com.br
#
#                                                  html  \
# 0   <!DOCTYPE html>\n<!--[if lt IE 7]>      <html ...
# 1   <!doctype html>\n<html lang="pt-br" data-tray-...
# 2   <!DOCTYPE html><html lang="pt-BR" xmlns:og="ht...
# 3   <!doctype html>\n<html lang="pt-br" class="pag...
# 4   <!doctype html>\n<html lang="pt-BR">\n<head>\n...
# ..                                                ...
# 91  <!DOCTYPE html>\n<!--[if lt IE 7]>      <html ...
# 92  <!DOCTYPE html>\n<html class='ltr' dir='ltr' x...
# 93  <!DOCTYPE html>\n<html class='v2' dir='ltr' la...
# 94  <!DOCTYPE html>\n<html class='v2' dir='ltr' xm...
# 95  <!DOCTYPE html>\n<html class='v2' dir='ltr' la...
#
#                                                tokens     processed_cnpjs  \
# 0   ['java', 'script', 'parecer', 'desabilitar', '...  ['17155356000105']
# 1   ['menu', 'vendido', 'lancamentos', 'conjunto',...                  []
# 2   ['fretar', 'gratis', 'brindar', 'exclusivo', '...  ['47542679000104']
# 3   ['primar', 'live', 'ajudar', 'suportar', 'cont...  ['03897520000137']
# 4   ['home', 'contar', 'carro', 'politicar', 'troc...                  []
# ..                                                ...                 ...
# 91  ['empresar', 'material', 'galeria', 'cliente',...                  []
# 92  ['home', 'sobrar', 'apoiar', 'pequeno', 'negoc...                  []
# 93  ['sabado', 'outubro', 'diy', 'cabeceira', 'cam...                  []
# 94  ['paginar', 'paginar', 'inicial', 'filme', 'se...                  []
# 95  ['terca', 'feirar', 'janeiro', 'vender', 'mod'...                  []
#
#     has_cnpj  count_prices  has_prices  pred_0_prob  pred_1_prob  prediction  \
# 0       True            49        True     0.000170     0.999830           1
# 1      False            51        True     0.001667     0.998333           1
# 2       True            31        True     0.000566     0.999434           1
# 3       True            49        True     0.000266     0.999734           1
# 4      False            27        True     0.003864     0.996136           1
# ..       ...           ...         ...          ...          ...         ...
# 91     False             0       False     0.901739     0.098261           0
# 92     False             6        True     0.975012     0.024988           0
# 93     False             0       False     0.999544     0.000456           0
# 94     False             0       False     0.998956     0.001044           0
# 95     False             0       False     0.999186     0.000814           0
#
#    true_prediction notes
# 0             True   NaN
# 1             True   NaN
# 2             True   NaN
# 3             True   NaN
# 4              NaN   NaN
# ..             ...   ...
# 91           False   NaN
# 92           False   NaN
# 93           False   NaN
# 94           False   NaN
# 95           False   NaN
#
# [96 rows x 13 columns]

# %%
df.loc[df['pred_1_prob'] >= range]
# Out:
#     Unnamed: 0                     domain  \
# 0            0       corpoeenergia.com.br
# 1            1          donnalimao.com.br
# 2            2       insumosdailha.com.br
# 3            3           primelive.com.br
# 4            4  santodesejosexshop.com.br
# 5            5      pedrinhosports.com.br
# 6            6           adaptogen.com.br
# 7            7        shoptalkmoda.com.br
# 8            8   pontodaeletronica.com.br
# 9            9  revivcestasbasicas.com.br
# 10          10         plannershop.com.br
# 11          11     revistamonolito.com.br
# 12          12      santapaciencia.com.br
# 13          13                brio.com.br
# 14          14          vimarboots.com.br
# 15          15       ammobeachwear.com.br
# 17          17             leparis.com.br
# 18          18               boxf1.com.br
# 19          19         pluckystore.com.br
# 20          20         powercellbh.com.br
# 21          21         dopaminefit.com.br
# 23          23       bordabordados.com.br
# 25          25          ladyfetish.com.br
# 27          27              donajo.com.br
# 29          29                levi.com.br
# 30          30        dpromocional.com.br
# 31          31        brasapedidos.com.br
# 32          32       domidonashoes.com.br
# 33          33    relogiodepontosp.com.br
# 36          36        combatcustom.com.br
#
#                                                  html  \
# 0   <!DOCTYPE html>\n<!--[if lt IE 7]>      <html ...
# 1   <!doctype html>\n<html lang="pt-br" data-tray-...
# 2   <!DOCTYPE html><html lang="pt-BR" xmlns:og="ht...
# 3   <!doctype html>\n<html lang="pt-br" class="pag...
# 4   <!doctype html>\n<html lang="pt-BR">\n<head>\n...
# 5   <!doctype html>\n<html lang="pt-br">\n<head>\n...
# 6   <!DOCTYPE html>\n<html class="no-js" lang="pt-...
# 7   <!DOCTYPE html><html lang="pt-BR"><head><meta ...
# 8   <!DOCTYPE html>\n<!--[if lt IE 7]>      <html ...
# 9   <!DOCTYPE html>\r\n<html data-pnotify-firstpos...
# 10  <!DOCTYPE html>\n\t<!--[if lt IE 7]>      <htm...
# 11  <!DOCTYPE html>\n<html lang="pt-BR">\n<head>\n...
# 12  <!-- This page is cached by the Hummingbird Pe...
# 13  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 S...
# 14  <!DOCTYPE html> <!--[if IE]><![endif]--> <!--[...
# 15  <!doctype html>\n<html class="no-js" lang="pt-...
# 17  \n<!DOCTYPE html>\n<html lang="pt-BR">\n<head>...
# 18  <!doctype html>\n<html class="no-js" lang="pt-...
# 19  <!DOCTYPE html>\n<html lang="pt-BR">\n<head>\n...
# 20  <!DOCTYPE html>\n<html lang="pt-BR" prefix="og...
# 21  <!DOCTYPE html>\r\n<html xmlns="http://www.w3....
# 23  <!DOCTYPE html>\n<!--[if lte IE 9]><html class...
# 25  <!DOCTYPE html>\n<html lang="pt">\n<head>\n  \...
# 27  <!doctype html>\n<html class="no-js" lang="pt-...
# 29  \n<!DOCTYPE html>\n  <html lang="pt-BR">\n  <h...
# 30  <!DOCTYPE html>\n<html lang="pt-br">\n<head>\n...
# 31  <!doctype html>\n<html lang="pt-BR">\n<head>\n...
# 32  <!doctype html><html lang="pt-BR" data-files="...
# 33  <!DOCTYPE html>\n<html dir="ltr" lang="pt-BR" ...
# 36  <!DOCTYPE html>\r\n<html lang="pt-BR">\r\n<hea...
#
#                                                tokens     processed_cnpjs  \
# 0   ['java', 'script', 'parecer', 'desabilitar', '...  ['17155356000105']
# 1   ['menu', 'vendido', 'lancamentos', 'conjunto',...                  []
# 2   ['fretar', 'gratis', 'brindar', 'exclusivo', '...  ['47542679000104']
# 3   ['primar', 'live', 'ajudar', 'suportar', 'cont...  ['03897520000137']
# 4   ['home', 'contar', 'carro', 'politicar', 'troc...                  []
# 5   ['social', 'instagram', 'lista', 'desejo', 'pe...  ['03820484000103']
# 6   ['parcelar', 'atar', 'juro', 'cartao', 'credit...  ['02844238000129']
# 7   ['lancamentos', 'acessorios', 'vestuario', 'bl...  ['24158860000116']
# 8   ['java', 'script', 'parecer', 'desabilitar', '...  ['05701783000154']
# 9   ['contato', 'entrar', 'menu', 'entrar', 'compa...  ['00975860000140']
# 10  ['java', 'script', 'seems', 'disabled', 'brows...  ['27914051000266']
# 11  ['search', 'menu', 'contar', 'entrar', 'regist...  ['12855059000140']
# 12  ['skip', 'content', 'facebook', 'instagram', '...  ['31381211000145']
# 13  ['telefone', 'veiculos', 'tatuape', 'santo', '...                  []
# 14  ['login', 'cadastrar', 'feminino', 'wedding', ...  ['12041457000123']
# 15  ['pular', 'conteudo', 'fretar', 'gratis', 'com...  ['34911405000101']
# 17  ['fretar', 'gratis', 'partir', 'moda', 'intima...                  []
# 18  ['pular', 'conteudo', 'iniciar', 'equipar', 'e...                  []
# 19  ['sac', 'pluckystore', 'home', 'plucky', 'loja...  ['39539059000198']
# 20  ['add', 'anything', 'remover', 'facebook', 'tw...                  []
# 21  ['fretar', 'gratis', 'acima', 'acessorios', 'f...                  []
# 23  ['icon', 'stock', 'notification', 'success', '...                  []
# 25  ['top', 'page', 'iniciar', 'loja', 'contato', ...                  []
# 27  ['pular', 'conteudo', 'fechar', 'menu', 'novid...                  []
# 29  ['fretar', 'gratis', 'acima', 'loja', 'feminin...                  []
# 30  ['ola', 'visitante', 'acessar', 'contar', 'cad...                  []
# 31  ['saltar', 'navegacao', 'pular', 'conteudo', '...                  []
# 32  ['domidona', 'shoe', 'estilo', 'elegante', 'em...  ['10910671000143']
# 33  ['info', 'relogiodepontosp', 'vendaspontoatecs...  ['27733494000170']
# 36  ['conteudo', 'pesquisar', 'resultar', 'ver', '...  ['39428338000184']
#
#     has_cnpj  count_prices  has_prices  pred_0_prob  pred_1_prob  prediction  \
# 0       True            49        True     0.000170     0.999830           1
# 1      False            51        True     0.001667     0.998333           1
# 2       True            31        True     0.000566     0.999434           1
# 3       True            49        True     0.000266     0.999734           1
# 4      False            27        True     0.003864     0.996136           1
# 5       True             1       False     0.003672     0.996328           1
# 6       True            48        True     0.000586     0.999414           1
# 7       True            14        True     0.000273     0.999727           1
# 8       True            43        True     0.001064     0.998936           1
# 9       True             8        True     0.006269     0.993731           1
# 10      True           175        True     0.000746     0.999254           1
# 11      True             3        True     0.010252     0.989748           1
# 12      True            14        True     0.002818     0.997182           1
# 13     False            31        True     0.030633     0.969367           1
# 14      True             6        True     0.000593     0.999407           1
# 15      True            17        True     0.000945     0.999055           1
# 17     False             6        True     0.033753     0.966247           1
# 18     False           133        True     0.007281     0.992719           1
# 19      True            10        True     0.003461     0.996539           1
# 20     False            37        True     0.070138     0.929862           1
# 21     False            28        True     0.023444     0.976556           1
# 23     False             2        True     0.021351     0.978649           1
# 25     False            38        True     0.007775     0.992225           1
# 27     False             8        True     0.020902     0.979098           1
# 29     False            31        True     0.005721     0.994279           1
# 30     False             0       False     0.073871     0.926129           1
# 31     False             2        True     0.042634     0.957366           1
# 32      True             0       False     0.004016     0.995984           1
# 33      True            47        True     0.007602     0.992398           1
# 36      True            47        True     0.004674     0.995326           1
#
#    true_prediction notes
# 0             True   NaN
# 1             True   NaN
# 2             True   NaN
# 3             True   NaN
# 4              NaN   NaN
# 5             True   NaN
# 6             True   NaN
# 7             True   NaN
# 8             True   NaN
# 9             True   NaN
# 10            True   NaN
# 11            True   NaN
# 12             NaN   NaN
# 13            True   NaN
# 14            True   NaN
# 15            True   NaN
# 17            True   NaN
# 18            True   NaN
# 19            True   NaN
# 20            True   NaN
# 21            True   NaN
# 23            True   NaN
# 25             NaN   NaN
# 27            True   NaN
# 29            True   NaN
# 30            True   NaN
# 31            True   NaN
# 32            True   NaN
# 33            True   NaN
# 36            True   NaN

# %%
range = 0.5
print(len(df.loc[df['pred_1_prob'] < range]))
df.loc[df['pred_1_prob'] < range].value_counts('true_prediction')
# Out:
# 50
# true_prediction
# False    49
# True      1
# Name: count, dtype: int64

# %% [markdown]
# # Confiance Report -> Range (correct/total)
# ## 0.9 - 1.0
# 27/27 -> 100%
# ## 0.8 - 1.0
# 28/29 -> 96.6%
# ## 0.7 - 1.0
# 29/31 -> 93.5%
# ## 0.6 - 1.0
# 33/35 -> 94.3%
# ## 0.5 - 1.0
# 34/40 -> 85.0%
# ## 0.0 - 0.5
# 49/50 -> 98.0%

# %% [markdown]
# # Confiance Report -> Range (correct/total)
# ## 0.9 - 1.0
# 9/9 -> 100%
# ## 0.8 - 1.0
# 17/18 -> 94.4%
# ## 0.7 - 1.0
# 25/27 -> 92.6%
# ## 0.6 - 1.0
# 31/37 -> 83.8%
# ## 0.5 - 1.0
# 35/47 -> 74.5%
# ## 0.0 - 0.5
# 43/43 -> 100%

# %%
idf_values = vectorizer.idf_
feature_importances = pd.DataFrame({'feature': feature_names, 'idf': idf_values})
feature_importances = feature_importances.sort_values(by='idf', ascending=False)
feature_importances

# %%
feature_importances.head(60)
